# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 19.3.1; however, version 20.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 19.3.1; however, version 20.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import sys
import time
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
try:
        #use the browser to get the url. This is suspicious command that might blow up.
    page=requests.get('https://www.cricbuzz.com')                             # this might throw an exception if something goes wrong.
    
except Exception as e:                                   # this describes what to do if an exception is thrown
    error_type, error_obj, error_info = sys.exc_info()      # get the exception information
    print ('ERROR FOR LINK:',url)                          #print the link that cause the problem
    print (error_type, 'Line:', error_info.tb_lineno)     #print error info and line that threw the exception
                                                 #ignore this page. Abandon this and go back.
time.sleep(2)   
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('div',attrs={'class':'cb-nws-intr'})

# %%
links
# Out:
# [<div class="cb-nws-intr">From Michael Holding's impassioned words on the BLM campaign to England's opening troubles to rain ruining play, it wasn't all that bad a return for cricket</div>,
#  <div class="cb-nws-intr">While the BCCI President announced this decision, the BCB and PCB said they were not aware of this move</div>,
#  <div class="cb-nws-intr">The application comes days after the CAG member raised the issue of eligibility of office-bearers of BCCI</div>,
#  <div class="cb-nws-intr">Graeme Smith stressed on the need of a stance relatable to South Africans in solidarity with the movement during the 3TC tournament</div>,
#  <div class="cb-nws-intr">The former Sunrisers Hyderabad Head Coach talks about fostering the IPL's most-envied bowling attack, and of course, the 18-year-old maverick he picked for four crores in 2017</div>,
#  <div class="cb-nws-intr">Former India captain - and current BCCI president - Sourav Ganguly turns 48 today</div>,
# ...

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# From Michael Holding's impassioned words on the BLM campaign to England's opening troubles to rain ruining play, it wasn't all that bad a return for cricket
#
#
# While the BCCI President announced this decision, the BCB and PCB said they were not aware of this move
#
#
# The application comes days after the CAG member raised the issue of eligibility of office-bearers of BCCI
#
#
# Graeme Smith stressed on the need of a stance relatable to South Africans in solidarity with the movement during the 3TC tournament
#
#
# The former Sunrisers Hyderabad Head Coach talks about fostering the IPL's most-envied bowling attack, and of course, the 18-year-old maverick he picked for four crores in 2017
#
#
# Former India captain - and current BCCI president - Sourav Ganguly turns 48 today
#
#
# The Pakistan Test skipper pointed out the need for his team to adapt to the new rules before the first Test against England
#
#
# ...

# %%
try:
        #use the browser to get the url. This is suspicious command that might blow up.
    page=requests.get('https://www.cricbuzz.com')                             # this might throw an exception if something goes wrong.
    
except Exception as e:                                   # this describes what to do if an exception is thrown
    error_type, error_obj, error_info = sys.exc_info()      # get the exception information
    print ('ERROR FOR LINK:',url)                          #print the link that cause the problem
    print (error_type, 'Line:', error_info.tb_lineno)     #print error info and line that threw the exception
                                                 #ignore this page. Abandon this and go back.
time.sleep(2)   
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('div',attrs={'class':'crd-cntxt'})

# %%
links
# Out:
# [<div class="crd-cntxt"><span>WEST INDIES TOUR OF ENGLAND</span></div>,
#  <div class="crd-cntxt"><span>ASIA CUP 2020</span></div>,
#  <div class="crd-cntxt">GOVERNANCE AND BCCI</div>,
#  <div class="crd-cntxt">SOUTH AFRICAN CRICKET</div>,
#  <div class="crd-cntxt"><span>CRICBUZZ IN CONVERSATION</span></div>,
#  <div class="crd-cntxt"><span>OTD</span></div>,
#  <div class="crd-cntxt">PAKISTAN TOUR OF ENGLAND, 2020</div>,
#  <div class="crd-cntxt">IRELAND CRICKET</div>,
#  <div class="crd-cntxt">CORRUPTION IN CRICKET</div>,
#  <div class="crd-cntxt">BANGLADESH CRICKET NEWS</div>,
#  <div class="crd-cntxt">CRICKET IN THE TIME OF COVID-19</div>,
#  <div class="crd-cntxt">DIVERSITY AND INCLUSION</div>,
#  <div class="crd-cntxt">FINALISING SCHEDULE</div>,
#  <div class="crd-cntxt">CONTRACT RENEWED </div>,
#  <div class="crd-cntxt">CPL 2020</div>,
#  <div class="crd-cntxt">T20 BLAST 2020</div>,
#  <div class="crd-cntxt">SRI LANKA CRICKET NEWS</div>]

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# WEST INDIES TOUR OF ENGLAND
#
#
# ASIA CUP 2020
#
#
# GOVERNANCE AND BCCI
#
#
# SOUTH AFRICAN CRICKET
#
#
# CRICBUZZ IN CONVERSATION
#
#
# OTD
#
#
# PAKISTAN TOUR OF ENGLAND, 2020
#
#
# IRELAND CRICKET
#
#
# CORRUPTION IN CRICKET
#
#
# BANGLADESH CRICKET NEWS
#
#
# CRICKET IN THE TIME OF COVID-19
#
#
# DIVERSITY AND INCLUSION
#
#
# FINALISING SCHEDULE
#
#
# CONTRACT RENEWED
#
#
# CPL 2020
#
#
# T20 BLAST 2020
#
#
# SRI LANKA CRICKET NEWS

# %%
try:
        #use the browser to get the url. This is suspicious command that might blow up.
    page=requests.get('https://www.cricbuzz.com')                             # this might throw an exception if something goes wrong.
    
except Exception as e:                                   # this describes what to do if an exception is thrown
    error_type, error_obj, error_info = sys.exc_info()      # get the exception information
    print ('ERROR FOR LINK:',url)                          #print the link that cause the problem
    print (error_type, 'Line:', error_info.tb_lineno)     #print error info and line that threw the exception
                                                 #ignore this page. Abandon this and go back.
time.sleep(2)   
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('a')

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# ✖
#
#
#
#
#
# Live Scores
#
#
# Schedule
#
#
# Archives
#
#
# News
#
#
# All Stories
#
#
# Latest News
#
#
# Topics
#
#
# Spotlight
#
#
# Opinions
#
#
# Specials
#
#
# Stats & Analysis
#
#
# Interviews
#
#
# Live Blogs
#
#
# Harsha Bhogle
#
#
# Series
#
#
# West Indies tour of England, 2020
#
#
# Ireland tour of England, 2020
#
#
# Pakistan tour of England, 2020
#
#
# West Indies tour of England Warm-up Matches, 2020
#
#
# ICC Womens T20 World Cup 2020
#
#
# Pakistan Super League 2020
#
#
# Bangladesh tour of Pakistan, 2020
#
#
# All Series »
#
#
# Teams
#
#
# India
#
#
# Ireland
#
#
# Pakistan
#
#
# Australia
#
#
# Sri Lanka
#
#
# Bangladesh
#
#
# England
#
#
# West Indies
#
#
# South Africa
#
#
# Zimbabwe
#
#
# New Zealand
#
#
# Afghanistan
#
#
# Iran
#
#
# Botswana
#
#
# Belgium
#
#
# Italy
#
#
# Namibia
#
#
# Denmark
#
#
# Singapore
#
#
# Netherlands
#
#
# Bermuda
#
#
# Canada
#
#
# Uganda
#
#
# Scotland
#
#
# More...
#
#
# Videos
#
#
# All Videos
#
#
# Categories
#
#
# ...

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
try:
        #use the browser to get the url. This is suspicious command that might blow up.
    page=requests.get('https://www.cricbuzz.com/cricket-team')                             # this might throw an exception if something goes wrong.
    
except Exception as e:                                   # this describes what to do if an exception is thrown
    error_type, error_obj, error_info = sys.exc_info()      # get the exception information
    print ('ERROR FOR LINK:',url)                          #print the link that cause the problem
    print (error_type, 'Line:', error_info.tb_lineno)     #print error info and line that threw the exception
                                                 #ignore this page. Abandon this and go back.
time.sleep(2)   
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('a', attrs={'class':'cb-subnav-item'})

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# All Stories
#
#
# Latest News
#
#
# Topics
#
#
# Spotlight
#
#
# Opinions
#
#
# Specials
#
#
# Stats & Analysis
#
#
# Interviews
#
#
# Live Blogs
#
#
# Harsha Bhogle
#
#
# West Indies tour of England, 2020
#
#
# Ireland tour of England, 2020
#
#
# Pakistan tour of England, 2020
#
#
# West Indies tour of England Warm-up Matches, 2020
#
#
# ICC Womens T20 World Cup 2020
#
#
# Pakistan Super League 2020
#
#
# Bangladesh tour of Pakistan, 2020
#
#
# All Series »
#
#
# India
#
#
# Ireland
#
#
# Pakistan
#
#
# Australia
#
#
# Sri Lanka
#
#
# Bangladesh
#
#
# England
#
#
# West Indies
#
#
# South Africa
#
#
# Zimbabwe
#
#
# New Zealand
#
#
# Afghanistan
#
#
# Iran
#
#
# Botswana
#
#
# Belgium
#
#
# Italy
#
#
# Namibia
#
#
# Denmark
#
#
# Singapore
#
#
# Netherlands
#
#
# Bermuda
#
#
# Canada
#
#
# Uganda
#
#
# Scotland
#
#
# All Videos
#
#
# Categories
#
#
# Playlists
#
#
# ICC Rankings - Men
#
#
# ICC Rankings - Women
#
#
# Quiz
#
#
# Photos
#
#
# Mobile Apps
#
#
# Careers
#
#
# ...

# %%
try:
        #use the browser to get the url. This is suspicious command that might blow up.
    page=requests.get('https://www.cricbuzz.com/cricket-team')                             # this might throw an exception if something goes wrong.
    
except Exception as e:                                   # this describes what to do if an exception is thrown
    error_type, error_obj, error_info = sys.exc_info()      # get the exception information
    print ('ERROR FOR LINK:',url)                          #print the link that cause the problem
    print (error_type, 'Line:', error_info.tb_lineno)     #print error info and line that threw the exception
                                                 #ignore this page. Abandon this and go back.
time.sleep(2)   
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('a', attrs={'class':'text-normal cb-team-item-text-inner'})

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# India
#
#
# Ireland
#
#
# Pakistan
#
#
# Australia
#
#
# Sri Lanka
#
#
# Bangladesh
#
#
# England
#
#
# West Indies
#
#
# South Africa
#
#
# Zimbabwe
#
#
# New Zealand
#
#
# Afghanistan
#
#
# Iran
#
#
# Botswana
#
#
# Belgium
#
#
# Italy
#
#
# Namibia
#
#
# Denmark
#
#
# Singapore
#
#
# Netherlands
#
#
# Bermuda
#
#
# Canada
#
#
# Uganda
#
#
# Scotland
#
#
# United Arab Emirates
#
#
# Hong Kong
#
#
# Kenya
#
#
# United States
#
#
# Malaysia
#
#
# Nepal
#
#
# Germany
#
#
# Vanuatu
#
#
# Jersey
#
#
# Oman
#
#
# Fiji
#
#
# Papua New Guinea
#
#
# Kuwait
